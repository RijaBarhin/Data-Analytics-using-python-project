# %% [markdown]
# <a href="https://colab.research.google.com/github/RijaBarhin/Data-Analytics-using-python-project/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# calculater

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
# Out:
# Enter first number: 10
# Enter second number: 20
# Addition = 30
# Subtraction = -10
# Multiplication = 200
# Division = 0.5

# %% [markdown]
# Expence tracker

# %%
expenses = {
    "Food": 200,
    "Travel": 150,
    "Shopping": 300
}

total = sum(expenses.values())

print("Expenses:")
for category, amount in expenses.items():
    print(category, ":", amount)

print("Total Expense =", total)
# Out:
# Expenses:
# Food : 200
# Travel : 150
# Shopping : 300
# Total Expense = 650

# %% [markdown]
# Grading system

# %%
mark = int(input("Enter your mark: "))

if mark >= 90:
    grade = "A"
elif mark >= 75:
    grade = "B"
elif mark >= 50:
    grade = "C"
else:
    grade = "F"

print("Grade:", grade)
# Out:
# Enter your mark: 85
# Grade: B
